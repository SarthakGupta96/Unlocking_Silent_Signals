# %%
import mediapipe as mp

# %%
import cv2

# %%
import os
import csv
import numpy as np

file_path = 'Dataset/coords.csv'
if not os.path.exists(file_path):
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    with open(file_path, mode='w', newline='') as f:
        writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        writer.writerow(['class'] + [f'pose_{i}' for i in range(132)] + [f'face_{i}' for i in range(1436)])

# %%
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_face_mesh = mp.solutions.face_mesh

# %%
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        results = holistic.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
        ##FACE
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_face_mesh.FACEMESH_TESSELATION,
                                 mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1)
                                )

        ##RIGHT HAND
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks,mp_holistic.HAND_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )
        ##LEFT HAND
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks,mp_holistic.HAND_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )
        ##POSE DETECTION
        mp_drawing.draw_landmarks(image, results.pose_landmarks,mp_holistic.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )

        cv2.imshow('Raw webcam feed',image)

        if cv2.waitKey(10) & 0xFF == ord('w'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
class_name = "Happy"

# Initialize video capture
cap = cv2.VideoCapture(0)

# Initialize MediaPipe Holistic and Drawing
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_face_mesh = mp.solutions.face_mesh

# Start the holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()

        # Recolor frame from BGR to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detections
        results = holistic.process(image)

        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_face_mesh.FACEMESH_TESSELATION,
                                 mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1)
                                
                                 )
        # Draw right hand landmarks
        mp_drawing.draw_landmarks(
            image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(80, 22, 10), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(80, 44, 121), thickness=2, circle_radius=2)
        )

        # Draw left hand landmarks
        mp_drawing.draw_landmarks(
            image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=2, circle_radius=2)
        )

        # Draw pose landmarks
        mp_drawing.draw_landmarks(
            image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
        )

        # Try to extract landmarks and write to CSV
        try:
            # Extract Pose landmarks
            if results.pose_landmarks and results.face_landmarks:
                pose = results.pose_landmarks.landmark
                face = results.face_landmarks.landmark
                ...
            pose_row = list(np.array([[lm.x, lm.y, lm.z, lm.visibility] for lm in pose]).flatten())

            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[lm.x, lm.y, lm.z, lm.visibility] for lm in face]).flatten())

            # Combine all landmarks
            row = pose_row + face_row

            # Insert class label
            row.insert(0, class_name)

            # Write to CSV
            with open('Dataset/coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)
                print(f"Logged: {class_name}, Length of row: {len(row)}")

        except Exception as e:
            print(f"Error writing to CSV: {e}")


        # Display image
        cv2.imshow('Raw Webcam Feed', image)

        # Break loop on 'q'
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Cleanup
cap.release()
cv2.destroyAllWindows()
# Out:
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005
# Logged: Happy, Length of row: 2005

# %%
class_name = "Sad"

# Initialize video capture
cap = cv2.VideoCapture(0)

# Initialize MediaPipe Holistic and Drawing
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_face_mesh = mp.solutions.face_mesh

# Start the holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()

        # Recolor frame from BGR to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detections
        results = holistic.process(image)

        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Draw face landmarks
        mp_drawing.draw_landmarks(
            image, results.face_landmarks, mp_face_mesh.FACEMESH_TESSELATION,
            mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
            mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1)
        )

        # Draw right hand landmarks
        mp_drawing.draw_landmarks(
            image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(80, 22, 10), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(80, 44, 121), thickness=2, circle_radius=2)
        )

        # Draw left hand landmarks
        mp_drawing.draw_landmarks(
            image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=2, circle_radius=2)
        )

        # Draw pose landmarks
        mp_drawing.draw_landmarks(
            image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
        )

        # Try to extract landmarks and write to CSV
        try:
            # Extract Pose landmarks
            if results.pose_landmarks and results.face_landmarks:
                pose = results.pose_landmarks.landmark
                face = results.face_landmarks.landmark
                ...
            pose_row = list(np.array([[lm.x, lm.y, lm.z, lm.visibility] for lm in pose]).flatten())

            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[lm.x, lm.y, lm.z, lm.visibility] for lm in face]).flatten())

            # Combine all landmarks
            row = pose_row + face_row

            # Insert class label
            row.insert(0, class_name)

            # Write to CSV
            with open('Dataset/coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)
                print(f"Logged: {class_name}, Length of row: {len(row)}")

        except Exception as e:
            print(f"Error writing to CSV: {e}")

        # Display image
        cv2.imshow('Raw Webcam Feed', image)

        # Break loop on 'q'
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Cleanup
cap.release()
cv2.destroyAllWindows()
# Out:
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Logged: Sad, Length of row: 2005
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Error writing to CSV: 'NoneType' object has no attribute 'landmark'
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005
# Logged: Sad, Length of row: 2005

# %%
class_name = "Victorious"
cap = cv2.VideoCapture(0)

# Initialize MediaPipe Holistic and Drawing
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_face_mesh = mp.solutions.face_mesh

# Start the holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()

        # Recolor frame from BGR to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detections
        results = holistic.process(image)

        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_face_mesh.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1))

        # Draw right hand landmarks
        mp_drawing.draw_landmarks(
            image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(80, 22, 10), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(80, 44, 121), thickness=2, circle_radius=2)
        )

        # Draw left hand landmarks
        mp_drawing.draw_landmarks(
            image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=2, circle_radius=2)
        )

        # Draw pose landmarks
        mp_drawing.draw_landmarks(
            image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
        )

        # Try to extract landmarks and write to CSV
        try:
            # Extract Pose landmarks
            if results.pose_landmarks and results.face_landmarks:
                pose = results.pose_landmarks.landmark
                face = results.face_landmarks.landmark
                ...
            pose_row = list(np.array([[lm.x, lm.y, lm.z, lm.visibility] for lm in pose]).flatten())

            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[lm.x, lm.y, lm.z, lm.visibility] for lm in face]).flatten())

            # Combine all landmarks
            row = pose_row + face_row

            # Insert class label
            row.insert(0, class_name)

            # Write to CSV
            with open('Dataset/coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)
                print(f"Logged: {class_name}, Length of row: {len(row)}")

        except Exception as e:
            print(f"Error writing to CSV: {e}")

        # Display image
        cv2.imshow('Raw Webcam Feed', image)

        # Break loop on 'q'
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Cleanup
cap.release()
cv2.destroyAllWindows()
# Out:
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005
# Logged: Victorious, Length of row: 2005

# %%
class_name = "Fight"

# Initialize video capture
cap = cv2.VideoCapture(0)

# Initialize MediaPipe Holistic and Drawing
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_face_mesh = mp.solutions.face_mesh

# Start the holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()

        # Recolor frame from BGR to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detections
        results = holistic.process(image)

        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_face_mesh.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1))

        # Draw right hand landmarks
        mp_drawing.draw_landmarks(
            image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(80, 22, 10), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(80, 44, 121), thickness=2, circle_radius=2)
        )

        # Draw left hand landmarks
        mp_drawing.draw_landmarks(
            image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=2, circle_radius=2)
        )

        # Draw pose landmarks
        mp_drawing.draw_landmarks(
            image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
        )

        # Try to extract landmarks and write to CSV
        try:
            # Extract Pose landmarks
            if results.pose_landmarks and results.face_landmarks:
                pose = results.pose_landmarks.landmark
                face = results.face_landmarks.landmark
                ...

            pose_row = list(np.array([[lm.x, lm.y, lm.z, lm.visibility] for lm in pose]).flatten())

            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[lm.x, lm.y, lm.z, lm.visibility] for lm in face]).flatten())

            # Combine all landmarks
            row = pose_row + face_row

            # Insert class label
            row.insert(0, class_name)

            # Write to CSV
            with open('Dataset/coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)
                print(f"Logged: {class_name}, Length of row: {len(row)}")

        except Exception as e:
            print(f"Error writing to CSV: {e}")

        # Display image
        cv2.imshow('Raw Webcam Feed', image)

        # Break loop on 'q'
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Cleanup
cap.release()
cv2.destroyAllWindows()
# Out:
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
# Logged: Fight, Length of row: 2005
